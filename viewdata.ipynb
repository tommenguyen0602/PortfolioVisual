# %%
import pandas as pd
signals = pd.read_csv("signal_details_final.csv")
filtered_df = signals[signals['Signal Id'] == "1885162"]
signals.describe()
# Out:
#           Signal Id  ProfitTrades   LossTrades  SharpeRatio  RecoveryFactor  \
# count  1.555000e+03   1555.000000  1555.000000  1555.000000     1555.000000
# mean   1.748293e+06    852.302251   352.381994     0.230733       26.286707
# std    2.442849e+05   2024.615441   794.879165     0.526887      171.232610
# min    8.527800e+04      3.000000     0.000000    -0.840000       -1.000000
# 25%    1.725798e+06     89.000000    28.000000     0.060000        0.810000
# 50%    1.833566e+06    257.000000    96.000000     0.120000        3.150000
# 75%    1.904566e+06    787.000000   318.000000     0.245000        8.550000
# max    1.943615e+06  27901.000000  8193.000000    12.180000     2881.690000
#
#        ProfitFactor  AlgoTrading
# count   1531.000000  1555.000000
# mean       7.913828    68.927331
# std       85.217292    41.678203
# min        0.110000     0.000000
# 25%        1.180000    18.500000
# 50%        1.630000    96.000000
# 75%        2.415000    99.000000
# ...
