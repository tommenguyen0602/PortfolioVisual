# %%
import pandas as pd
signals = pd.read_csv("signal_details.csv")
signals
# Out:
#     Signal Id Trades  ProfitTrades  LossTrades BestTrades WorstTrades
# 0     1368342  1 853        1310.0       543.0     807.28     -443.63  \
# 1     1636506    200         153.0        47.0     133.49      -80.75
# 2      843451  1 110         784.0       326.0     254.65     -276.76
# 3     1486477    519         398.0       121.0      94.36     -260.41
# 4     1818780    364         231.0       133.0   1 768.00     -879.20
# 5     1598419    469         300.0       169.0   1 793.00   -1 894.46
# 6     1245170  3 057        1945.0      1112.0      16.48      -13.65
# 7     1722050    387         269.0       118.0   1 759.00     -875.60
# 8     1725375  1 420        1043.0       377.0     366.09     -257.81
# 9     1334849    788         598.0       190.0      44.96      -57.80
# 10    1712504  1 945        1472.0       473.0      68.66     -381.89
# 11    1857419    947         682.0       265.0      49.50      -43.90
# ...
