# %%
import pandas as pd
signals = pd.read_csv("signal_details_final.csv")
filtered_df = signals[signals['Signal Id'] == "1885162"]
signals
# Out:
#     Signal Id Trades  ProfitTrades  LossTrades BestTrades WorstTrades
# 0     1368342  1 887        1327.0       560.0     807.28     -443.63  \
# 1     1636506    209         161.0        48.0     133.49      -80.75
# 2      843451  1 121         789.0       332.0     254.65     -276.76
# 3     1486477    557         419.0       138.0     161.35     -770.90
# 4     1818780    365         232.0       133.0   1 768.00     -879.20
# ..        ...    ...           ...         ...        ...         ...
# 88    1503574  1 182         835.0       347.0      18.08      -27.78
# 89    1102360  6 926        5230.0      1696.0     566.42     -138.85
# 90    1774107    901         654.0       247.0     840.71      -25.36
# 91    1802508    130         106.0        24.0      27.01     -195.09
# 92    1342817    308         219.0        89.0     354.64     -111.84
#
#    GrossProfit   GrossLoss  SharpeRatio  RecoveryFactor  ProfitFactor
# ...
